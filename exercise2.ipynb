# %%
import datetime


'''
ASSIGNMENT BEGINNING

You are supposed to create a script which
- calculates a day of today while using datetime.datetime.today() method
- calculates a month of today
- prints information upon today's season, so if the month number is:
    - <=3 then spring
    - <=6 then spring
    - <=9 then fall
    - <=12 then winter

'''
#datetime of today
today = datetime.datetime.today()
# month of today
today_month = today.month

#testing number of month against conditions
if today_month <=3:
    season = 'spring'
elif today_month <=6:
    season = 'summer'
elif today_month <=9:
    season = 'fall'
elif today_month <=12:
    season = 'winter'

print(f'It is a month of number {today_month} and it is {season}')

'''
ASSIGNMENT END
'''



'''
ASSIGNMENT BEGINNING

Re-use the code you have just made and create a function which takes one mandatory (positional)
argument and then tests this argument value against the condition. Give the function a name "check_season".
User will be allowed to call this function and give it a month number whereas he will got back info upon the season
of that month.
'''


# function testing number of month againts conditions
def check_season(month_number):
    if month_number <=3:
        season = 'spring'
    elif month_number <=6:
        season = 'summer'
    elif month_number <=9:
        season = 'fall'
    elif month_number <=12:
        season = 'winter'
    # printing out a message for a user
    print(f'It is a month of number {month_number} and it is {season}')
    
# function call
check_season(5)

'''
ASSIGNMENT END
'''


'''
ASSIGNMENT BEGINNING

Create a script which
- has a variable trip_season (give it value winter)
- works with the dictionary below
- finds a user list of locations which are good to go in that season. So find that season in dictionaries
keys and then return this key list of values.
'''

#dictonary
locations = {
    # key: values type of list
    'winter':['malta','monaco', 'london'],
    'spring':['athens','lisbon','budapest'],
    'summer':['tenerife','madrid','florence'],
    'fall': ['amsterdam','turin','gdansk']  
}

# a varible of type string
trip_season = 'winter'
# printing a message to a user
print(f'in {trip_season} I recommend you to go to one of these destinations: {locations[trip_season]}')

'''
ASSIGNMENT END
'''



'''
ASSIGNMENT BEGINNING

Create variablies:
- trip_season
- trip_country

Then iterate over the dictionary below and print out to a user a list of cities
which are good to go in a particular season in a particular country. 
'''


# a variable of type dictionary
destinations = {
    #key
    'winter':{
        #key: # values of type list
        'germany':['berlin','hannover'],
        'italy':['bolzano','bergamo'],
        'france':['nice']},
    'spring':{
        'germany':['berlin','munich'],
        'italy':['florence','milan'],
        'france':['bordeaux','nice']},
    'summer':{
        'germany':['hannover','dresden'],
        'italy':['bari','rome'],
        'france':['paris','lyon']},

    'fall':{
        'germany':['frankfurt am main','munich'],
        'italy':['palermo','milan'],
        'france':['paris','marseille']}}

# varibles of type string
trip_season = 'winter'
trip_country = 'germany'
# printing out a message for a user
print(f'I recommend going to one of these destinations: {destinations[trip_season][trip_country]}')

'''
ASSIGNMENT END
'''


'''
ASSIGNMENT BEGINNING

Re-use the dictonary above
- create a variable selected_destionation, you can give it a value hannover
- iterate over the dictionary and print out info, which season do you recommend to a user to go to that location.
In a case of hannover, the season is summer.
In case of berlin, the season is winter and then spring

'''


# a varible of type string
selected_destination = 'berlin'

# iteration over keys and values of dictionary items
for k,v in destinations.items():
    #iteration over keys and values of dictionary (we are iterating over dictionaries of a dictinary)
    for kk,vv in v.items():        
            # iteration over items ina a list (we are iterating over values which are type of list)
            for i in vv:
                if i == selected_destination:
                #printing a message for a user which contains a top level's key
                    print(f'I recommend going there in {k}')

                    
'''
ASSIGNMENT END
'''

'''
ASSIGNMENT BEGINNING
Create a script which contains
- an empty variable customer_with_life_insurance which is type of list (empty so far)
- iterates over the dictionary below and if a value of a key equals to life insurance, then
add that key into the list you just created.
- at the end, prints out the list of customers id (keys) with life insurance
'''

# a variable of type empty list
customers_with_life_insurance = []

# a variable of type dictonary
customers = {
    # key: value of type string
    1:'life insurance',
    2:'property insurance',
    3:'life insurance',
    4: 'life insurance'}

#iteration over dictonary keys and values
for k,v in customers.items():
    #testing a key against a condition
    if v == 'life insurance':
        # if the condition is met, add the key into the list
        customers_with_life_insurance.append(k)

#printing a message for a user
print(f'list of customers id with life insurance: {customers_with_life_insurance}')

'''
ASSIGNMENT END
'''


'''
ASSIGNMENT BEGINNING
Create a script which iterates over the dictionary below and if a value si "paid", remove
that key from list list_of_debtors.
At the end, print the list_list_of_debtors
'''

# a variable of type list of integers
list_of_debtors = [1,2,10,15,50]

# a variable of type dictonary
customers_payments = {
    #key:value
    1:'paid',
    2:'unpaid',
    10:'paid',
    15:'paid',
    50:'unpaid'
}



for k,v in customers_payments.items():
    if v == 'paid':
        list_of_debtors.remove(k)
    else:
        pass

print(f' debtors: {list_of_debtors}')

'''
ASSIGNMENT END
'''

'''
ASSIGNMENT BEGINNING

Create a script which contains
- a variable customer_to-check which of type empty list
- iterates over the dictionary below and
    - stores product_id value into a variable product_id
    - stores payment_info value into a variable payment_status 
- if the product_id equals to 1 and payments_status equals to unpaid then add the key (customer id)
into the list customers_to_check

'''

# a variable of type dictonary
customers_payments_products = {
    #key: a value of type dictonary (we have dictionary of dictionaries)
    1:{'product_id':1,'payment_info':'unpaid'},
    2:{'product_id':2,'payment_info':'paid'},
    3:{'product_id':1,'payment_info':'paid'},
    4:{'product_id':1,'payment_info':'paid'}}

# a variable of type empty list
customers_to_check = []

# iteration over keys and values of a dictionary
for k,v in customers_payments_products.items():
    # a variable of type integer whereas the id is taken from keys value
    product_id = customers_payments_products[k]['product_id']
    # a variable of type string whereas the id is taken from keys value
    payment_status = customers_payments_products[k]['payment_info']
    
    # testing a variables values against two conditions whereas both conditions must be met
    if (product_id == 1) and (payment_status == 'unpaid'):
        # if both conditions are met, add a key into the list customers_to-check
        customers_to_check.append(k)

# printing out a message for user        
print(customers_to_check)

'''
ASSIGNMENT END
'''
# Out:
# It is a month of number 12 and it is winter
# It is a month of number 5 and it is summer
# in winter I recommend you to go to one of these destinations: ['malta', 'monaco', 'london']
# I recommend going to one of these destinations: ['berlin', 'hannover']
# I recommend going there in winter
# I recommend going there in spring
# list of customers id with life insurance: [1, 3, 4]
#  debtors: [2, 50]
# [1]
